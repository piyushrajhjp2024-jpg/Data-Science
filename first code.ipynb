# %% [markdown]
# # wap ask the user enter a basic salary
# # wap ask  the user enter da amount
# # ask the user enter hra amount
# # calculate total pay = basic_salary+da+hra

# %% [markdown]
# #

# %% [markdown]
# ### Question 1

# %%
basic_salary=eval(input("enter a basic salary:"))
da=eval(input("enter da amount:"))
hra=eval(input("enter hra amount:"))
total_salary=basic_salary+da+hra
print("The total salary is:",total_salary)
# Out:
# enter a basic salary: 21000
# enter da amount: 9000
# enter hra amount: 9000
# The total salary is: 39000

# %% [markdown]
# # wap ask the user enter salary
# # ask the user tax percentage
# # calculate how much tax user need to pay

# %% [markdown]
# ### Question 2

# %%
Total_salary=eval(input("enter a salary of employee:"))
Tax_percentage=eval(input("what percentage of tax government charge:"))
tax_paying=(Total_salary*Tax_percentage)/100
print("the total paid is :",tax_paying)
remaining_amount=Total_salary-tax_paying
print("the actual amount:",remaining_amount)
# Out:
# enter a salary of employee: 120000
# what percentage of tax government charge: 15
# the total paid is : 18000.0
# the actual amount: 102000.0

# %% [markdown]
# # wap ask the user get a random valur between 1 to 100
# # perform the square of the number
#
# # package name: random
# # method name : randint

# %% [markdown]
# ### Question 3

# %%
import random
square_number= random.randint(1,100)
x="The random number is:",square_number
print(x)
number=square_number*square_number
print("square of  is :",number)
# Out:
# ('The random number is:', 6)
# square of  is : 36

# %%
# this is the number to identify the square of random number

# %% [markdown]
# # wap ask the user enter a distance
# # ask the user enter a rate per distance
# # calculate total charge=20*2=40

# %% [markdown]
# ### Question 4

# %%
import random
distance=random.randint(1,20)
x="the distance is:",distance
print(distance)
fare_price=distance*25
print("actal fare price is:",fare_price)
# Out:
# 1
# actal fare price is: 25

# %%
# random value of distance travelled in km in correspondance to it's fare price

# %% [markdown]
# #### ask the user enter total bill in dollar
# ### manager: the dollar are not accepted
# ### user: what will accepted
# ### manager: only indian rupees
# ### askthe user enter one dollar is equal to how much rupees :80
# ### total bill= 100*80
# ### manager: Thank You!

# %% [markdown]
# ### Question 5

# %%
import time
user=eval(input("enter the bill in dollar:"))
x=user
time.sleep(2) #for wait for 2sec after getting a result 
user1=eval(input("1 dollar equal to how many rupees:"))
y=user1
total_bill=(x*y)
print("Total bill in rupees is:",x*y)   
print("Manager-Thamk you so much !")
# Out:
# enter the bill in dollar: 678
# 1 dollar equal to how many rupees: 89
# Total bill in rupees is: 60342
# Manager-Thamk you so much !

# %% [markdown]
# -FATHER AND SON
# -FATHER: WHICH COURSE YOU WANT TO DO
# -SON: I WANT TO PURSUE DS COURSE
# -FATHER: OH!THAT IS VERY NICE
# -FATHER:MAY I KNOW YOUR JEE RANK
# -SON:300000
# -FATHER:THEN HOW CAN YOU PURSUE
# -SON:PAYMENT SEAT
# -FATHER: WHICH COLLEGE IS OFFERING
# -SON:NARESH IT
# -FATHER: HOW MUCH IS THE FEE
# -SON:20000
# -FATHER:HOW MANY SEM
# -SON:4
# -FATHER:HOW MUCH TOTAL SEAT
# -4*20000

# %% [markdown]
# #### Question 6

# %% [markdown]
# ### print("FATHER AND SON")
# time.sleep(3)
# print("FATHER: WHICH COURSE YOU WANT TO DO ")
# time.sleep(3)
# print("-SON: I WANT TO PURSUE DS COURSE")
# time.sleep(3)
# print("FATHER: OH!THAT IS VERY NICE")
# time.sleep(3)
# print("FATHER:MAY I KNOW YOUR JEE RANK")
# time.sleep(3)
# x=eval(input("my jee rank is:"))
# time.sleep(3)
# print("FATHER:THEN HOW CAN YOU PURSUE")
# time.sleep(3)
# print("SON:PAYMENT SEAT")
# time.sleep(3)
# print("which college is offering")
# y=input(str())
# time.sleep(3)
# print("FATHER: HOW MUCH IS THE FEE")
# time.sleep(3)
# z=eval(input("fees:"))
# time.sleep(3)
# print("FATHER:HOW MANY SEM")
# time.sleep(3)
# q=eval(input("total sem  is:"))
# time.sleep(3)
# print("FATHER:HOW MUCH TOTAL fees")
# time.sleep(3)
# r=z*q
# print("total fees is :",r)
# time.sleep(3)
# ("OK THAT'S GOOD")
